# %% [markdown]
# # 프로젝트명: 데이터 수집 실습 2 (공공데이터포털 API로 받기)
#
# #### 📌 requests는 API를 호출할 때 주로 사용하는 라이브러리입니다.
# - 서버에 HTTP 요청을 보낼때 주로 사용하며, GET, POST, PUT, DELETE를 사용할 수 있습니다.
# - 데이터 API의 요구사항에 맞게 요청해야하며, 보통은 "GET", "POST"를 주로 사용됩니다.
#
# #### 🚨 주의사항
# - 공공데이터포털에선 운영계정을 신청해서 **서비스키**를 받아야합니다.
# - 자세한 내용은 보통 API 사용문서를 참고합니다.
#
# ![dddd](https://firebasestorage.googleapis.com/v0/b/ls-storage-e452a.appspot.com/o/%E1%84%80%E1%85%A9%E1%86%BC%E1%84%80%E1%85%A9%E1%86%BC%E1%84%83%E1%85%A6%E1%84%8B%E1%85%B5%E1%84%90%E1%85%A5_api.png?alt=media&token=4f62a990-1274-4785-8fa7-8611e1bdc91b)

# %% [markdown]
# ### 1일 차이의 사이 값 가져오기

# %%
from datetime import datetime, timedelta

start_date = datetime.strptime('2021-10-20', '%Y-%m-%d')
end_date = datetime.strptime('2021-10-31', '%Y-%m-%d')

date_range = []
for i in range((end_date - start_date).days + 1):
    res_date = start_date + timedelta(days=i)
    res_date = res_date.strftime('%Y-%m-%d')
    date_range.append(res_date)
    
print(date_range)
# Out:
# ['2021-10-20', '2021-10-21', '2021-10-22', '2021-10-23', '2021-10-24', '2021-10-25', '2021-10-26', '2021-10-27', '2021-10-28', '2021-10-29', '2021-10-30', '2021-10-31']

# %% [markdown]
# ### 1년 차이의 한달 간격 가져오기

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

start_date = datetime.strptime('2021-10-20', '%Y-%m-%d')
end_date = datetime.strptime('2021-10-31', '%Y-%m-%d')

date_range = []
current_date = start_date
while current_date < end_date:
    res_date = current_date.strftime('%Y-%m-%d')
    date_range.append(res_date)
    current_date += relativedelta(months=1)

print(date_range)
# Out:
# ['2021-10-20']

# %% [markdown]
# ### 기상청의 2023년 서울의 데이터 가져오기 (1년치 데이터 가져오기)

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

start_date = datetime.strptime('2023-01-01', '%Y-%m-%d')
end_date = datetime.strptime('2024-01-01', '%Y-%m-%d')

date_range = []
current_date = start_date
while current_date < end_date:
    res_date = current_date.strftime('%Y%m%d')
    date_range.append(res_date)
    current_date += relativedelta(months=1)

print(date_range)
# Out:
# ['20230101', '20230201', '20230301', '20230401', '20230501', '20230601', '20230701', '20230801', '20230901', '20231001', '20231101', '20231201']

# %%
start_end_date = []
for i in range(len(date_range) -1):
    start_end_date.append([date_range[i], date_range[i+1]])

# %%
from tqdm import tqdm
import requests
import pandas as pd
import time

url = 'http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList'
key = '''수정'''

dfs = []
for i in tqdm(start_end_date):
    print(i)

    params = {'serviceKey' : key, 
            'pageNo' : '1', 
            'numOfRows' : '999', 
            'dataType' : 'JSON', 
            'dataCd' : 'ASOS', ## 자료분류코드
            'dateCd' : 'HR', ## 날짜분류코드
            'startDt' : str(i[0]), ## 시작일
            'startHh' : '00', ## 시작시간
            'endDt' : str(i[1]), ## 종료일
            'endHh': '00', ## 종료시간
            'stnIds' : '131' ## 청주지역코드
            }

    response = requests.get(url, params=params,verify=False)
    result = response.json()
    df = pd.DataFrame(result['response']['body']['items']['item'])
    dfs.append(df)

final_df = pd.concat(dfs, axis=0, ignore_index=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# ['20230101', '20230201']
#   9%|▉         | 1/11 [00:01<00:16,  1.68s/it]
# ['20230201', '20230301']
#  18%|█▊        | 2/11 [00:03<00:16,  1.82s/it]
# ['20230301', '20230401']
#  27%|██▋       | 3/11 [00:04<00:12,  1.53s/it]
# ['20230401', '20230501']
#  36%|███▋      | 4/11 [00:07<00:14,  2.13s/it]
# ['20230501', '20230601']
#  45%|████▌     | 5/11 [00:08<00:10,  1.77s/it]
# ['20230601', '20230701']
#  55%|█████▍    | 6/11 [00:10<00:08,  1.75s/it]
# ['20230701', '20230801']
#  64%|██████▎   | 7/11 [00:15<00:11,  2.85s/it]
# ['20230801', '20230901']
#  73%|███████▎  | 8/11 [00:16<00:06,  2.29s/it]
# ['20230901', '20231001']
#  82%|████████▏ | 9/11 [00:18<00:03,  1.93s/it]
# ['20231001', '20231101']
#  91%|█████████ | 10/11 [00:19<00:01,  1.69s/it]
# ['20231101', '20231201']
# 100%|██████████| 11/11 [00:20<00:00,  1.84s/it]

# %%
final_df
# Out:
#                     tm rnum stnId stnNm    ta taQcflg   rn rnQcflg   ws  \
# 0     2023-01-01 00:00    1   131    청주  -2.5                    9  0.0
# 1     2023-01-01 01:00    2   131    청주  -3.0                       0.0
# 2     2023-01-01 02:00    3   131    청주  -3.3                       0.0
# 3     2023-01-01 03:00    4   131    청주  -3.5                       0.0
# 4     2023-01-01 04:00    5   131    청주  -3.5                       0.0
# ...                ...  ...   ...   ...   ...     ...  ...     ...  ...
# 8022  2023-11-30 20:00  717   131    청주  -1.8                       0.6
# 8023  2023-11-30 21:00  718   131    청주  -1.9                       1.6
# 8024  2023-11-30 22:00  719   131    청주  -2.1                       1.3
# 8025  2023-11-30 23:00  720   131    청주  -2.0                       1.4
# 8026  2023-12-01 00:00  721   131    청주  -2.1          0.0          1.3
#
#      wsQcflg  ... lcsCh    vs gndSttCd dmstMtphNo    ts tsQcflg m005Te m01Te  \
# 0             ...         753                  19  -1.2
# 1             ...         703                  19  -1.7
# 2             ...         683                  19  -2.1
# 3             ...         666                  19  -2.5
# 4             ...    10   726                  19  -2.8
# ...      ...  ...   ...   ...      ...        ...   ...     ...    ...   ...
# 8022          ...        4520                      -1.6
# 8023          ...    11  4668                      -1.8
# 8024          ...    10  4384                      -1.8
# 8025          ...     8  3855                  05  -1.0
# 8026          ...        3370                  05  -1.0
#
#      m02Te m03Te
# 0
# 1
# 2
# 3
# 4
# ...    ...   ...
# 8022
# 8023
# 8024
# 8025
# 8026
#
# [8027 rows x 38 columns]

# %%
## final_df의 결측치 확인
final_df.isnull().sum()
# Out:
# tm            0
# rnum          0
# stnId         0
# stnNm         0
# ta            0
# taQcflg       0
# rn            0
# rnQcflg       0
# ws            0
# wsQcflg       0
# wd            0
# wdQcflg       0
# hm            0
# hmQcflg       0
# pv            0
# td            0
# pa            0
# paQcflg       0
# ps            0
# psQcflg       0
# ss            0
# ssQcflg       0
# icsr          0
# dsnw          0
# hr3Fhsc       0
# dc10Tca       0
# dc10LmcsCa    0
# clfmAbbrCd    0
# lcsCh         0
# vs            0
# gndSttCd      0
# dmstMtphNo    0
# ts            0
# tsQcflg       0
# m005Te        0
# m01Te         0
# m02Te         0
# m03Te         0
# dtype: int64

# %%
final_df['tm'] = pd.to_datetime(final_df['tm'])

# %%
final_df['date'] = final_df['tm'].dt.date
final_df['hour'] = final_df['tm'].dt.hour

# %%
final_df.groupby('date').size().reset_index(name='count').sort_values('count', ascending=False)
# Out:
#            date  count
# 212  2023-08-01     25
# 90   2023-04-01     25
# 59   2023-03-01     25
# 151  2023-06-01     25
# 243  2023-09-01     25
# ..          ...    ...
# 112  2023-04-23     24
# 111  2023-04-22     24
# 110  2023-04-21     24
# 109  2023-04-20     24
# 334  2023-12-01      1
#
# [335 rows x 2 columns]

# %%
final_df[final_df['date'] == '2023-08-01']
# Out:
# Empty DataFrame
# Columns: [tm, rnum, stnId, stnNm, ta, taQcflg, rn, rnQcflg, ws, wsQcflg, wd, wdQcflg, hm, hmQcflg, pv, td, pa, paQcflg, ps, psQcflg, ss, ssQcflg, icsr, dsnw, hr3Fhsc, dc10Tca, dc10LmcsCa, clfmAbbrCd, lcsCh, vs, gndSttCd, dmstMtphNo, ts, tsQcflg, m005Te, m01Te, m02Te, m03Te, date, hour]
# Index: []
#
# [0 rows x 40 columns]

# %%
final_df['date'] = final_df['date'].astype(str)

# %%
final_df[final_df['date'] == '2023-08-01']
# Out:
#                       tm rnum stnId stnNm    ta taQcflg   rn rnQcflg   ws  \
# 5094 2023-08-01 00:00:00  745   131    청주  28.1                       2.0
# 5095 2023-08-01 00:00:00    1   131    청주  28.1                       2.0
# 5096 2023-08-01 01:00:00    2   131    청주  27.3                       1.9
# 5097 2023-08-01 02:00:00    3   131    청주  26.6                       1.6
# 5098 2023-08-01 03:00:00    4   131    청주  26.2                       1.9
# 5099 2023-08-01 04:00:00    5   131    청주  26.1                       1.7
# 5100 2023-08-01 05:00:00    6   131    청주  25.6                       1.3
# 5101 2023-08-01 06:00:00    7   131    청주  25.3                       1.4
# 5102 2023-08-01 07:00:00    8   131    청주  26.0                       1.3
# 5103 2023-08-01 08:00:00    9   131    청주  27.6                       1.3
# 5104 2023-08-01 09:00:00   10   131    청주  29.3                       0.9
# 5105 2023-08-01 10:00:00   11   131    청주  31.1                       0.9
# 5106 2023-08-01 11:00:00   12   131    청주  32.7                       1.4
# 5107 2023-08-01 12:00:00   13   131    청주  33.5                       1.1
# 5108 2023-08-01 13:00:00   14   131    청주  34.3                       1.4
# 5109 2023-08-01 14:00:00   15   131    청주  33.9                       0.6
# 5110 2023-08-01 15:00:00   16   131    청주  35.0                       0.9
# 5111 2023-08-01 16:00:00   17   131    청주  34.7                       1.3
# 5112 2023-08-01 17:00:00   18   131    청주  34.9                       1.4
# 5113 2023-08-01 18:00:00   19   131    청주  33.3          0.0          3.9
# 5114 2023-08-01 19:00:00   20   131    청주  32.6                    9  3.3
# 5115 2023-08-01 20:00:00   21   131    청주  32.0                    9  2.0
# 5116 2023-08-01 21:00:00   22   131    청주  31.2                    9  1.0
# 5117 2023-08-01 22:00:00   23   131    청주  30.7                    9  0.5
# 5118 2023-08-01 23:00:00   24   131    청주  30.1                    9  0.7
#
#      wsQcflg  ... gndSttCd dmstMtphNo    ts tsQcflg m005Te m01Te m02Te m03Te  \
# 5094          ...                      27.2
# 5095          ...                      27.2
# 5096          ...                      27.1
# 5097          ...                      26.6
# 5098          ...                      26.3
# 5099          ...                      26.2
# 5100          ...                      26.0
# 5101          ...                      26.0
# 5102          ...                      27.6
# 5103          ...                      30.9
# 5104          ...                      37.9
# 5105          ...                      43.7
# 5106          ...                      48.3
# 5107          ...                      48.8
# 5108          ...                      51.4
# 5109          ...                      41.5
# 5110          ...                      46.6
# 5111          ...                      45.1
# 5112          ...                      39.7
# 5113          ...                  04  37.4
# 5114          ...                      34.2
# 5115          ...                      30.8
# 5116          ...                      30.2
# 5117          ...                      29.7
# 5118          ...                      29.0
#
#             date hour
# 5094  2023-08-01    0
# 5095  2023-08-01    0
# 5096  2023-08-01    1
# 5097  2023-08-01    2
# 5098  2023-08-01    3
# 5099  2023-08-01    4
# 5100  2023-08-01    5
# 5101  2023-08-01    6
# 5102  2023-08-01    7
# 5103  2023-08-01    8
# 5104  2023-08-01    9
# 5105  2023-08-01   10
# 5106  2023-08-01   11
# 5107  2023-08-01   12
# 5108  2023-08-01   13
# 5109  2023-08-01   14
# 5110  2023-08-01   15
# 5111  2023-08-01   16
# 5112  2023-08-01   17
# 5113  2023-08-01   18
# 5114  2023-08-01   19
# 5115  2023-08-01   20
# 5116  2023-08-01   21
# 5117  2023-08-01   22
# 5118  2023-08-01   23
#
# [25 rows x 40 columns]

# %%
final_df['stnNm'].unique()
# Out:
# array(['청주'], dtype=object)
